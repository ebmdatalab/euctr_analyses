# %%
import pandas as pd
import numpy as np

# %%
spon_df = pd.read_csv('jan_spon_info.csv').drop('Unnamed: 0', axis=1)

# %%
spon_df.head()
# Out:
#          trial_id protocol_country  \
# 0  2011-000593-54               IT
# 1  2004-000534-36               SK
# 2  2017-004497-33               DK
# 3  2009-010198-19               SE
# 4  2017-000048-17               DK
#
#                                         sponsor_name sponsor_country  \
# 0  AZIENDA OSPEDALIERA L. SACCO (A.O. DI RILIEVO ...           Italy
# 1                          Laboratoires Expanscience          France
# 2         Copenhagen University Hospital at Hvidovre         Denmark
# 3                        Novartis Pharma Services AG     Switzerland
# 4                                   Novo Nordisk A/S         Denmark
#
#    sponsor_status
# 0  Non-Commercial
# 1      Commercial
# 2  Non-Commercial
# 3      Commercial
# 4      Commercial

# %%
norm = pd.read_excel('normalized_sponsor_names_jan.xlsx')
trials_csv = pd.read_csv('trials_jan.csv')
trials = trials_csv[['trial_id', 'number_of_countries', 'has_results', 'results_expected']].drop_duplicates()

# %%
sample = spon_df[(spon_df.sponsor_country == 'Austria')].reset_index(drop=True)
sample1 = sample.drop_duplicates()

# %%
merged = sample.merge(trials, on='trial_id', how='left')
merged['name_of_sponsor_lower'] = merged.sponsor_name.str.lower().str.replace(' ', '').str.replace('[^\w\s]','')

# %%
norm_s = norm[['name_of_sponsor', 'normalized_name']].reset_index(drop=True)
norm_s['name_of_sponsor_lower'] = norm.name_of_sponsor.str.lower().str.replace(' ', '').str.replace('[^\w\s]','')

# %%
with_norm = merged.merge(norm_s, on='name_of_sponsor_lower', how='left', indicator=True)

# %%
with_norm[with_norm._merge == 'left_only']
# Out:
#             trial_id protocol_country  \
# 799   2005-004866-17               DE
# 2533  2012-002002-46               AT
#
#                                            sponsor_name sponsor_country  \
# 799   Dept Medicine I, Paracelsus Med. Univ.\tLandes...         Austria
# 2533  Universitätsklinik für Zahn-, Mund- und Kiefer...         Austria
#
#       sponsor_status  number_of_countries  has_results  results_expected  \
# 799   Non-Commercial                  2.0          0.0               1.0
# 2533  Non-Commercial                  NaN          NaN               NaN
#
#                                   name_of_sponsor_lower name_of_sponsor  \
# 799   deptmedicineiparacelsusmeduniv\tlandeskrankena...             NaN
# 2533  universitätsklinikfürzahnmundundkieferheilkund...             NaN
#
#      normalized_name     _merge
# 799              NaN  left_only
# 2533             NaN  left_only

# %%
errors = with_norm[with_norm._merge == 'left_only'].index.values.tolist()

# %%
errors
# Out:
# [799, 2533]

# %%
for e in errors:
    if 'nodata' in with_norm.at[e,'name_of_sponsor_lower']:
        with_norm.at[e,'normalized_name'] = 'No Sponsor Name Given'
    elif 'universitätsklinikfürzahnmundundkieferheil' in with_norm.at[e,'name_of_sponsor_lower']:
        with_norm.at[e,'normalized_name'] = 'Medical University of Graz'
    elif 'deptmedicineiparacelsusmeduniv\tland' in with_norm.at[e,'name_of_sponsor_lower']:
        with_norm.at[e,'normalized_name'] = 'Paracelsus Medical University'

# %%
with_norm.head()
# Out:
#          trial_id protocol_country              sponsor_name sponsor_country  \
# 0  2016-001478-14               IT  Baxalta Innovations GmbH         Austria
# 1  2016-001478-14               CZ  Baxalta Innovations GmbH         Austria
# 2  2016-001478-14               NL  Baxalta Innovations GmbH         Austria
# 3  2016-001478-14               ES  Baxalta Innovations GmbH         Austria
# 4  2016-001478-14               DE  Baxalta Innovations GmbH         Austria
#
#   sponsor_status  number_of_countries  has_results  results_expected  \
# 0     Commercial                  7.0          0.0               0.0
# 1     Commercial                  7.0          0.0               0.0
# 2     Commercial                  7.0          0.0               0.0
# 3     Commercial                  7.0          0.0               0.0
# 4     Commercial                  7.0          0.0               0.0
#
#     name_of_sponsor_lower           name_of_sponsor           normalized_name  \
# 0  baxaltainnovationsgmbh  Baxalta Innovations GmbH  Baxalta Innovations GmbH
# 1  baxaltainnovationsgmbh  Baxalta Innovations GmbH  Baxalta Innovations GmbH
# 2  baxaltainnovationsgmbh  Baxalta Innovations GmbH  Baxalta Innovations GmbH
# 3  baxaltainnovationsgmbh  Baxalta Innovations GmbH  Baxalta Innovations GmbH
# 4  baxaltainnovationsgmbh  Baxalta Innovations GmbH  Baxalta Innovations GmbH
#
#   _merge
# 0   both
# 1   both
# 2   both
# 3   both
# 4   both

# %%
with_norm.rename(columns={'sponsor_name': 'euctr_name'}, inplace=True)

# %%
almost_df = with_norm[['trial_id','sponsor_country', 'normalized_name', 'sponsor_status', 'results_expected', 
                       'has_results']]

final_df = almost_df[almost_df.has_results.notnull()].reset_index(drop=True)
final_df['results_expected'] = final_df.results_expected.astype(int)
final_df['has_results'] = final_df.has_results.astype(int)
final_df['due_with_results'] = np.where((final_df.has_results == 1) & (final_df.results_expected == 1), 1,0)
final_df['trial_count'] = 1
final_df['commercial'] = np.where(final_df['sponsor_status'] == 'Commercial',1,0)
final_df['non-commercial'] = np.where(final_df['sponsor_status'] == 'Non-Commercial',1,0)

# %%
final_df.dtypes
# Out:
# trial_id            object
# sponsor_country     object
# normalized_name     object
# sponsor_status      object
# results_expected     int64
# has_results          int64
# due_with_results     int64
# trial_count          int64
# commercial           int64
# non-commercial       int64
# dtype: object

# %%
final_df.drop_duplicates(inplace=True)
final_df.head()
# Out:
#           trial_id sponsor_country  \
# 0   2016-001478-14         Austria
# 7   2010-021044-17         Austria
# 8   2010-018471-26         Austria
# 13  2015-003714-24         Austria
# 14  2009-017137-22         Austria
#
#                                   normalized_name  sponsor_status  \
# 0                        Baxalta Innovations GmbH      Commercial
# 7                    Medical University of Vienna  Non-Commercial
# 8                            Boehringer Ingelheim      Commercial
# 13  Biomedizinische Forschungsgesellschaft m.b.H.      Commercial
# 14                     Medical University of Graz  Non-Commercial
#
#     results_expected  has_results  due_with_results  trial_count  commercial  \
# 0                  0            0                 0            1           1
# 7                  1            1                 1            1           0
# 8                  1            1                 1            1           1
# 13                 0            0                 0            1           1
# 14                 0            0                 0            1           0
#
#     non-commercial
# 0                0
# 7                1
# 8                0
# 13               0
# 14               1

# %%
final_df.groupby('normalized_name').sum().to_csv('summary_counts.csv')

# %%
final_df.to_csv('combined_sponsor_info_austria.csv')
